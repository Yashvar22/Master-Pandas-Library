# %%
import numpy as np;
import pandas as pd;

# %% [markdown]
# **GroupBy**

# %%
data = {
    'Category': ['A', 'B', 'A', 'B', 'A', 'B', 'A', 'B'],
    'Store': ['S1', 'S1', 'S2', 'S2', 'S1', 'S2', 'S2', 'S1'],
    'Sales': [100, 200, 150, 250, 120, 180, 200, 300],
    'Quantity': [10, 15, 12, 18, 8, 20, 15, 25],
    'Date': pd.date_range('2023-01-01', periods=8)
}
df = pd.DataFrame(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 6
#       1 data = {
#       2     'Category': ['A', 'B', 'A', 'B', 'A', 'B', 'A', 'B'],
#       3     'Store': ['S1', 'S1', 'S2', 'S2', 'S1', 'S2', 'S2', 'S1'],
#       4     'Sales': [100, 200, 150, 250, 120, 180, 200, 300],
#       5     'Quantity': [10, 15, 12, 18, 8, 20, 15, 25],
# ----> 6     'Date': pd.date_range('2023-01-01', periods=8)
#       7 }
#       8 df = pd.DataFrame(data)
#
# NameError: name 'pd' is not defined

# %%
df
# Out:
#   Category Store  Sales  Quantity       Date
# 0        A    S1    100        10 2023-01-01
# 1        B    S1    200        15 2023-01-02
# 2        A    S2    150        12 2023-01-03
# 3        B    S2    250        18 2023-01-04
# 4        A    S1    120         8 2023-01-05
# 5        B    S2    180        20 2023-01-06
# 6        A    S2    200        15 2023-01-07
# 7        B    S1    300        25 2023-01-08

# %%
#Group by cateogoty and calculate the sum of Sales
cat = df.groupby('Category')['Sales'].sum()

# %%
cat
# Out:
# Category
# A    570
# B    930
# Name: Sales, dtype: int64

# %%
df.groupby('Store')['Sales'].sum()
# Out:
# Store
# S1    720
# S2    780
# Name: Sales, dtype: int64

# %%
#Group by multiple column
#group by Cateogoty and store
cat = df.groupby(['Category','Store'])['Sales'].sum()

# %%
cat
# Out:
# Category  Store
# A         S1       220
#           S2       350
# B         S1       500
#           S2       430
# Name: Sales, dtype: int64

# %% [markdown]
# **Aggregation**

# %%
df['Sales'].mean()
"""mean median mode min max count std"""
# Out:
# np.float64(187.5)

# %%
df['Sales'].agg(['mean','median','min','max','std'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df['Sales'].agg(['mean','median','min','max','std'])
#
# NameError: name 'df' is not defined
